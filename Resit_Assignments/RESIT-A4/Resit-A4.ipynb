# %% [markdown]
# # Resit Assignment 4
#
#
#
# **Deadline for Assignment: Friday, November 25, 2022 (5pm) via Canvas (Resit Assignment 4)**
#
#
# * Please submit your complete assignment (scripts, notebook) by compressing all your material into **a single .zip file** following this naming convention: RESIT_A4_FIRSTNAME_LASTNAME.zip.
#
#
# Please post your questions on Piazza or email us (cltl.python.course@gmail.com).
#
# In this block, we covered the following chapters about data formats:
#
# - Chapter 16 - Data Formats I (CSV/TSV)
# - Chapter 17 - Data Formats II (JSON)
#
#
# In this assignment, you will also have to apply your knowledge about containers. If you get stuck, you are likely to find solutions in the chapters about containers (Block 2). Exercises and concepts we have treated in the lectures may also be relevant.

# %% [markdown]
# # Data
#
# In this assignment, you are going to work with a dataset in csv format. The dataset is called Best Books Ever and was retrieved from Goodreads.com. You can find more information here: https://github.com/scostap/goodreads_bbe_dataset
#
# Please download the csv file in this folder: https://github.com/scostap/goodreads_bbe_dataset/tree/main/Best_Books_Ever_dataset

# %% [markdown]
# # Part A: CSV dataset
#
# ### Exercise A1:
#
# Load the data as a list of dictionaries and explore the structure of the dataset (print a couple of lines, see what they contain, etc.). Use the csv module for this.

# %%
import csv

# %%
# adapt following cell to load your data with the csv module:

path = '/Users/piasommerauer/Data/goodreads_bbe_dataset/Best_Books_Ever_dataset/books_1.Best_Books_Ever.csv'
with open(path) as infile:
    data = list(csv.DictReader(infile))

# %%
# explore the data here
# Tip: use one row and inspect it

test_row = data[4]
for header, v in test_row.items():
    print(header, v)
# Out:
# bookId 41865.Twilight
# title Twilight
# series The Twilight Saga #1
# author Stephenie Meyer
# rating 3.60
# description About three things I was absolutely positive.
#
# First, Edward was a vampire.
#
# Second, there was a part of him—and I didn't know how dominant that part might be—that thirsted for my blood.
#
# And third, I was unconditionally and irrevocably in love with him.
#
# Deeply seductive and extraordinarily suspenseful, Twilight is a love story with bite.
# language English
# isbn 9780316015844
# genres ['Young Adult', 'Fantasy', 'Romance', 'Vampires', 'Fiction', 'Paranormal', 'Paranormal Romance', 'Supernatural', 'Teen', 'Urban Fantasy']
# characters ['Edward Cullen', 'Jacob Black', 'Laurent', 'Renee', 'Bella Swan', 'Billy Black', 'Esme Cullen', 'Alice Cullen', 'Jasper Hale', 'Carlisle Cullen', 'Emmett Cullen', 'Rosalie Hale', 'Charlie Swan', 'Mike Newton', 'Jessica Stanley', 'Angela Weber', 'Tyler Crowley']
# bookFormat Paperback
# edition
# pages 501
# ...

# %% [markdown]
# ### Exercise A2:
#
# When exploring the data, you will have realized that some cells are filled with strings that look like python lists. To work with these values properly, we want to convert them to lists.
#
# Python makes it very easy to convert stringified lists to lists. Consider the example below:

# %%
real_list = eval("['Edward Cullen', 'Jacob Black', 'Laurent', 'Renee', 'Bella Swan']")

# %% [markdown]
# Time to apply this to the dataset!
#
# Consider the function blow called `convert_cells_to_list`. Apply the function to the dataset (represented as a list of dicts) in such a way that all cells that contain stringified lists are converted to python lists. For example, the cells containing information about awards (header: 'award') should be converted to a python list containing all award names as strings. Carry out the following steps:
#
# * Inspect the dataset to find out which columns have to be converted
# * Look at the function definition and figure out how you can pass column names as inputs
# * Apply the function to the dataset in such a way that all cells containing list data are converted

# %%
def convert_cells_to_list(data, keys = ['awards']):
    """Convert given cells in table data from strings to lists."""
    for d in data:
        for k in keys:
            real_list = eval(d[k])
            d[k] = real_list

# %%
# warm-up 1: apply the function defined above to the data. 
#First find out which columns need to be converted, then specify the target column names using the 
# keyword parameter 'keys'.
convert_cells_to_list(data, keys = ['awards'])

# %%
# explore result:
for header, value in data[2].items():
    print(header, type(value))
    print(value)
    print()
# Out:
# bookId <class 'str'>
# 2657.To_Kill_a_Mockingbird
#
# title <class 'str'>
# To Kill a Mockingbird
#
# series <class 'str'>
# To Kill a Mockingbird
#
# author <class 'str'>
# Harper Lee
#
# rating <class 'str'>
# 4.28
#
# description <class 'str'>
# ...

# %% [markdown]
# # Part B: Convert to json files
#
# In this part of the assignment, we ask you to convert the original csv dataset to three json files. The purpose of converting to these files is that we can use them to search for books based on authors, awards, and settings without having to process the csv file line by line.  The format of the json files is explained below:
#
#
# ### authors.json
#
# A json file organized as follows (using the Harper Lee example):
#
# * Level 1: author name - dict
# * Level 2: book title - dict
# * Level 3: book information (original csv row) not containing author and title
#
# ```
# {
#     "Harper Lee" : {
#
#        'To Kill a Mockingbird': {
#               'bookId': '2657.To_Kill_a_Mockingbird',
#               'series': 'To Kill a Mockingbird',
#               'rating': '4.28',
#               'description': 'The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it, To Kill A Mockingbird became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, To Kill A Mockingbird takes readers to the roots of human behavior - to innocence and experience, kindness and cruelty, love and hatred, humor and pathos. Now with over 18 million copies in print and translated into forty languages, this regional story by a young Alabama woman claims universal appeal. Harper Lee always considered her book to be a simple love story. Today it is regarded as a masterpiece of American literature.',
#               'language': 'English',
#               'isbn': '9999999999999',
#               'genres': ['Classics',
#                'Fiction',
#                'Historical Fiction',
#                'School',
#                'Literature',
#                'Young Adult',
#                'Historical',
#                'Novels',
#                'Read For School',
#                'High School'],
#               'characters': ['Scout Finch',
#                'Atticus Finch',
#                'Jem Finch',
#                'Arthur Radley',
#                'Mayella Ewell',
#                'Aunt Alexandra',
#                'Bob Ewell',
#                'Calpurnia (housekeeper)',
#                'Tom Robinson',
#                'Miss Maudie Atkinson',
#                'Judge John Taylor',
#                'Dill Harris',
#                'Heck Tate',
#                'Stephanie Crawford'],
#               'bookFormat': 'Paperback',
#               'edition': '',
#               'pages': '324',
#               'publisher': 'Harper Perennial Modern Classics',
#               'publishDate': '05/23/06',
#               'firstPublishDate': '07/11/60',
#               'awards': ['Pulitzer Prize for Fiction (1961)',
#                'Audie Award for Classic (2007)',
#                'National Book Award Finalist for Fiction (1961)',
#                'Alabama Author Award for Fiction (1961)'],
#               'numRatings': '4501075',
#               'ratingsByStars': ['2363896', '1333153', '573280', '149952', '80794'],
#               'likedPercent': '95',
#               'setting': ['Maycomb', 'Alabama (United States)'],
#               'coverImg': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1553383690l/2657.jpg',
#               'bbeScore': '2269402',
#               'bbeVotes': '23328',
#               'price': ''},
#
#      "Go Set a Watchman": {}
#
#     "Author 2" : { ...},
#
# }
#
# ```
#
# ### awards.json
#
# * Level 1: award name (without year) - dict
# * Level 2: book title - dict
# * Level 3: book information (original csv row) with information about when the award was received and not containing the award name and title
#
#
# ```
# {
#     'Pulitzer Prize for Fiction': {
#         {'To Kill a Mockingbird': {
#               'year received': '1961',
#               'bookId': '2657.To_Kill_a_Mockingbird',
#               'series': 'To Kill a Mockingbird',
#               'author': 'Harper Lee',
#               'rating': '4.28',
#               'description': 'The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it, To Kill A Mockingbird became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, To Kill A Mockingbird takes readers to the roots of human behavior - to innocence and experience, kindness and cruelty, love and hatred, humor and pathos. Now with over 18 million copies in print and translated into forty languages, this regional story by a young Alabama woman claims universal appeal. Harper Lee always considered her book to be a simple love story. Today it is regarded as a masterpiece of American literature.',
#               'language': 'English',
#               'isbn': '9999999999999',
#               'genres': ['Classics',
#                'Fiction',
#                'Historical Fiction',
#                'School',
#                'Literature',
#                'Young Adult',
#                'Historical',
#                'Novels',
#                'Read For School',
#                'High School'],
#               'characters': ['Scout Finch',
#                'Atticus Finch',
#                'Jem Finch',
#                'Arthur Radley',
#                'Mayella Ewell',
#                'Aunt Alexandra',
#                'Bob Ewell',
#                'Calpurnia (housekeeper)',
#                'Tom Robinson',
#                'Miss Maudie Atkinson',
#                'Judge John Taylor',
#                'Dill Harris',
#                'Heck Tate',
#                'Stephanie Crawford'],
#               'bookFormat': 'Paperback',
#               'edition': '',
#               'pages': '324',
#               'publisher': 'Harper Perennial Modern Classics',
#               'publishDate': '05/23/06',
#               'firstPublishDate': '07/11/60',
#               'numRatings': '4501075',
#               'ratingsByStars': ['2363896', '1333153', '573280', '149952', '80794'],
#               'likedPercent': '95',
#               'setting': ['Maycomb', 'Alabama (United States)'],
#               'coverImg': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1553383690l/2657.jpg',
#               'bbeScore': '2269402',
#               'bbeVotes': '23328',
#               'price': ''},
#  'The Color Purple': {...},
#  ...
#
# ```
#
#
# ### settings.json
#
# * Level 1: setting - dict
# * Level 2: book title - dict
# * Level 3: book information (original csv row) not containing the setting and title
#
#
# ### Tips
#
#
# *Awards*
#
# Many of the awards end with the year in which the award was given (e.g. 'Pulitzer Prize for Fiction (1961)'). Please separate the year from the award name, so you can collect all books that received an award (regardless of the year they received it in). Please store the informatin about the year in the dictionary containing information about the book (using they key 'year received'). You can use string slicing to separate award name from year (usually, the last 6 characters of the award name refer to the year). In some cases, the award name does not have information about the year. If this is the case, 'year received' should have the value 'unknown'. Use a particular string method to test if the last six characters of the string (without the brackets) consist of digits.
#
# *Code structure and testing (asserts)*
#
# First write functions that return dictinaries. Then store them in json files using a separate function. We have prepared assert statements for you below. Please use them to test if your dictionaries are correct.
#
#
# *Defaultdict*
#
# It is highly recommended to use defaultdict for this exercise (see code example below).
#
#
#
#
# ### Submission
#
#
# Write functions to convert to the json files mentioned above. Please submit a single script called `convert2json.py` which carries out all three conversions. The resulting json files should be stored at a location that can be specified by the user. The location of the original csv dataset should also be specified by the user. Please have a look at the following script and use the same principle in your code: `command_line_arguments.py`. Run the script from your terminal as follows:
#
# `python command_line_arguments.py hello world`
#
# You can replace 'hello' and 'world' with any other words.  You can also have a look at tutorials such as this one: https://www.tutorialspoint.com/python/python_command_line_arguments.htm
#
#
# Don't forget to include and call the function `convert_cells_to_list())`, so you can access the values in cells containing lists.

# %%
# authors
assert len(author_dict['Zadie Smith']) == 4, "Problem in author dict."

# %%
# awards
assert list(award_dict["Women’s prize for fiction"].keys()) == ['Half of a Yellow Sun'], 'Problem in award dict'

# %%
# settings
assert len(setting_dict['London']) == 732, "Problem with setting dict"

# %%
# defaultdict

from collections import defaultdict


my_books = [
    {'title': 'book1', 'setting': 'London', 'author': 'author1'},
     {'title': 'book2', 'setting': 'Amsterdam', 'author': 'author2'},
     {'title': 'book3', 'setting': 'London', 'author': 'author3'},
     {'title': 'book4', 'setting': 'New York', 'author': 'author4'},
     {'title': 'book5', 'setting': 'New York', 'author': 'author5' }
    
    ]

settings_dict = defaultdict(dict)

for d in my_books:
    setting = d['setting']
    title = d['title']
    author = d['author']
    settings_dict[setting][title] = author
    
settings_dict

# %% [markdown]
# # Part C: Analysis script
#
# Create a script called `book_analysis.py`. The script should print answers to the following questions:
#
# * Print the name or names of the author(s) who has/have won the highest number of awards
# * Print the 5 most popular literary settings
# * Which books set in London have won any of the Booker Prize? Provide the authors and titles. *Tip: Use set methods to compare titles across datasets (awards and settings)*
#
# Use your json files to search the dataset (rather than the original csv file).
#
# ### Submission
#
# Submit your script.
