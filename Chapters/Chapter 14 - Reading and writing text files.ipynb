# %% [markdown]
# # Chapter 14: Reading and writing text files
# *We use some materials from [this other Python course](https://github.com/kadarakos/python-course).*

# %% [markdown]
# In this chapter, you will learn how to read data from files, do some analysis, and write the results to disk.
#
# Reading and writing files are quite an essential part of programming  as it is the first step for your program to communicate with the outside world. In most cases you will write programs that take data from some source, manipulates it in someway and writes some results out somewhere.
#
# For example, if you would write a survey, you could take input from participants on a webserver and save their answers in some files or in a database. When the survey is over, you would read these results in and do some analysis on the data you have collected, maybe do some visualizations and save your results.
#
# In **NLP**, you often process files containing raw texts with some code and write the results to some other file.
#
# ### At the end of this chapter, you will be able to:
#
# * open one or multiple text files
# * work with the modules `os` and `glob`
# * read the contents of a file
# * write new or manipulated content to new (or existing) files
# * close a file
#
#
# ### If you want to learn more about these topics, you might find the following links useful:
#
# * [Video: File Objects - Reading and Writing to Files](https://www.youtube.com/watch?v=Uh2ebFW8OYM)
# * [Video: Automate Parsing and Renaming of Multiple Files](https://www.youtube.com/watch?v=ve2pmm5JqmI)
# * [Video: OS Module - Use Underlying Operating System Functionality](https://www.youtube.com/watch?v=tJxcKyFMTGo)
# * [Blog post: 6 Ways the Linux File System is Different From the Windows File System](http://www.howtogeek.com/137096/6-ways-the-linux-file-system-is-different-from-the-windows-file-system/)
# * [Blog post: Gotcha — backslashes in Windows filenames](https://pythonconquerstheuniverse.wordpress.com/2008/06/04/gotcha-%E2%80%94-backslashes-in-windows-filenames/)
#
# If you have **questions** about this chapter, please contact **Marten (m.c.postma@vu.nl)**.

# %% [markdown]
# # 1. Reading a file

# %% [markdown]
# In Python, you can read the content of a file, store it as the type of object that you need (string, list, etc.) and manipulate it (e.g., replacing or removing words). You can also write new content to an existing or a new file.
#
# Here, we will discuss how to:
#
# * open a file
# * read in the content
# * store the context in a variable (to do something) e.g., as a string or list
# * close the file

# %% [markdown]
# ## 1.1. File paths

# %% [markdown]
# To open a file, we need to associate the file on disk with a variable in Python. First, we tell Python **where the file is stored on your disk**. The **location of your file** is often referred to as the **file path**.
#
# Python will start looking in the 'working' or 'current' directory (which often will be where your Python script is). If it's in the working directory, you only have to tell Python the name of the file (e.g., `charlie.txt`). If it's not in the working directory, as in our case, you have to tell Python the exact path to your file. We will create a string variable to store this information:

# %%
filename = "../Data/Charlie/charlie.txt"  

# The double dots mean 'go up one level in the directory tree'.

# %% [markdown]
# Sometimes you see double dots in the beginning of the file path; this means 'the parent of the current directory'. When writing a file path, you can use the following:
#
# - /     means the root of the current drive;
# - ./    means the current directory;
# - ../   means the parent of the current directory.
#
# Consider the directory tree below.
#
# * If you want to go from your current working directory (**cwd**) to the one directly above (dir3), your path is ../.
# * If you want to go to dir1, you path is ../../
# * If you want to go to dir5, your path is ../dir5/
# * If you want to go to dir2, your path is ../../dir2/
#
# You will learn how to navigate your directory tree quite intuitively with a bit of practice. If you have any doubts, it is always a good idea to follow a quick tutorial on basic command line operations.

# %% [markdown]
# <img src='images/directory_tree.png'>

# %% [markdown]
# **Navigating your directory tree on Windows**
#
# Also note that the formatting of file paths is different across operating systems. The file path as specified above should work on any UNIX platform (Linux, Mac). If you are using Windows, however, you might run into problems when formatting file paths in this way **outside of this notebook**, because Windows uses backslashes instead of forward slashes (Jupyter Notebook should already have taken care of these problems for you). In that case, it might be useful to have a look at [this page](http://www.howtogeek.com/137096/6-ways-the-linux-file-system-is-different-from-the-windows-file-system/) about the differences between the file systems, and at [this page](https://pythonconquerstheuniverse.wordpress.com/2008/06/04/gotcha-%E2%80%94-backslashes-in-windows-filenames/) about solving this problem in Python. In short, it's probably best if you use the code below (we will talk about the `os` module in more detail later today). This is very useful to know if you are a Windows user, and it will become relevant for the final assignment.

# %%
# For windows: 
import os
windows_file_path = os.path.normpath("C:/somePath/someFilename") # Use forward slashes

# %% [markdown]
# ## 1.2 Opening a file

# %% [markdown]
# We can use the file path to tell Python which file to open by using the built-in function `open()`. The `open()` function does not return the actual text that is saved in the text file. It returns a 'file object' from which we can read the content using the `.read()` function (more on this later). We pass three arguments to the `open()` function:
#
# * the **path to the file** that you wish to open
# * the **mode**, a combination of characters explaining the purpose of the file opening (like read or write) and type of content stored in the file (like textual or binary format). For instance, if we are reading a plain text file, we can use the characters 'r' (represents read-mode) and 't' (represents plain text-mode).
# * the last argument, a keyword argument (**encoding**), specifies the encoding of the text file, but you can forget about this for now.
#
# The most important **mode** arguments the `open()` function can take are:
#
# * **r** = Opens a file for reading only. The file pointer is placed at the beginning of the file.
# * **w** = Opens a file for writing only. Overwrites the file if the file exists. If the file does not exist, creates a new file for writing.
# * **a** = Opens a file for appending. The file pointer is at the end of the file if the file exists. If the file does not exist, it creates a new file for writing. Use it if you would like to add something to the end of a file
#
# Then, to open the file 'charlie.txt' for reading purposes, we use the following:

# %%
filepath = "../Data/Charlie/charlie.txt"  
infile = open(filepath, "r") # 'r' stands for READ mode
# Do something with the file
infile.close() # Close the file (you can ignore this for now)

# %% [markdown]
# Overview of possible mode arguments (the most important ones are 'r', 'w' and 'w'):
#
# | Character | Meaning |
# | --------- | ------- |
# |'r' |	open for reading (default)|
# |'w' |	open for writing, truncating the file first|
# |'x' |	open for exclusive creation, failing if the file already exists|
# |'a' |	open for writing, appending to the end of the file if it exists|
# |'b' |	binary mode|
# |'t' |	text mode (default)|
# |'+' |	open a disk file for updating (reading and writing)|
# |'U' |	universal newlines mode (deprecated)|

# %% [markdown]
# We could also directly use the path in the `open()``;

# %%
infile = open("../Data/Charlie/charlie.txt" , "r")
infile.close()

# %% [markdown]
# So far, we have opened the file. This, however, does not yet show us the file content. Try printing 'infile':

# %%
infile = open("../Data/Charlie/charlie.txt" , "r")
print(infile)
infile.close()
# Out:
# <_io.TextIOWrapper name='../Data/Charlie/charlie.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# This `TextIOWrapper` thing is Python's way of saying it has *opened* a connection to the file `charlie.txt`. To actually see its content, we need to tell python to read the file.

# %% [markdown]
# ## 1.3 Reading a file

# %% [markdown]
# Here, we will discuss three ways of reading the contents of a file:
#
# * `read()`
# * `readlines()`
# * `readline()`

# %% [markdown]
# ### 1.3.1 `read()`

# %% [markdown]
# The `read()` method is used to access the **entire text in a file**, which we can assign to a variable. Consider the code below.
#
# The variable `content` now holds the entire content of the file `charlie.txt` as a single string and we can access and manipulate it just like any other string. When we are done with accessing the file, we use the `close()` method to close the file.

# %%
# Opening the file using the filepath and and the 'read' mode:
infile = open("../Data/Charlie/charlie.txt" , "r")

# Reading the file using the `read()` function and assigning it to the variable `content`
content = infile.read()
print(content)
print()
print('This function returns a', type(content))

# closing the file (more on this below)
infile.close()
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.
#
# This function returns a <class 'str'>

# %% [markdown]
# ### 1.3.2  `readlines()`

# %% [markdown]
# The `readlines()` function allows you to access the content of a file as a list of lines. This means, it splits the text in a file at the new lines characters ('\n') for you):

# %%
# Opening the file using the filepath and and the 'read' mode:
infile = open("../Data/Charlie/charlie.txt" , "r")

# Reading the file using the `read()` function and assigning it to the variable `content`
lines = infile.readlines()
print(lines)
print()
print('This function returns a', type(lines))

# closing the file 
infile.close()
# Out:
# ['Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells. \n', '\n', 'Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.']
#
# This function returns a <class 'list'>

# %% [markdown]
# Now you can, for example, use a for-loop to print each line in the file (note that the second line is just a newline character):

# %%
for line in lines:
    print("LINE:", line)
# Out:
# LINE: Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# LINE:
#
# LINE: Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.

# %% [markdown]
# **Important note**
#
# When we open a file, we can only use one of the read operations **once**. If we want to read it again, we have to open a new file variable. Consider the code below:

# %%
infile = open("../Data/Charlie/charlie.txt" , "r")
content = infile.read()
lines = infile.readlines()
print(content)
print(lines)
infile.close()
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.
# []

# %% [markdown]
# The code returns an empty list. To fix this, we have to open the file again:

# %%
filepath = "../Data/Charlie/charlie.txt"

infile = open(filepath , "r")
content = infile.read()
infile = open(filepath, "r")
lines = infile.readlines()
print(content)
print(lines)
infile.close()
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.
# ['Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells. \n', '\n', 'Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.']

# %% [markdown]
# ### 1.3.3 `Readline()`

# %% [markdown]
# The third operation `readline()` returns the next line of the file, returning the text up to and including the next newline character (*\n*, or *\r\n* on Windows). More simply put, this operation will read a file line-by-line. So if you call this operation again, it will return the next line in the file. Try it out below!

# %%
filepath = "../Data/Charlie/charlie.txt"

infile = open(filepath, "r")
next_line = infile.readline()
print(next_line)
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.

# %%
next_line = infile.readline()
print(next_line)

# %%
next_line = infile.readline()
print(next_line)
infile.close()
# Out:
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.

# %% [markdown]
# **Which function to choose**
#
# For small files that you want to load entirely, you can use one of these three methods (readline, read, or readlines). Note, however, that we can also simply do the following to read a file line by line (this is recommended for larger files and when we are really only interested in a small portion of the file):

# %%
infile = open(filename, "r")
for line in infile:
    print(line)
infile.close()
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
#
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.

# %% [markdown]
# Note the last line of this code snippet: `infile.close()`. This closes our file, which is a very important operation. This prevents Python of keeping files that are unneccessary anymore still open. In the next subchapter we will also see a more convenient way to ensure files get closed after their usage.

# %% [markdown]
# ## 1.4. Closing the file
#
# Here, we will intorduce closing a file with the method `close()` and using a **context manager** to open and close files. After reading the contents of a file, the `TextWrapper` no longer needs to be open since we have stored the content as a variable. In fact, it is good practice to close the file as soon as you do not need it anymore.

# %% [markdown]
# ### 1.4.1  `close()`

# %% [markdown]
#  We do this by using the `close()` method as already shown several times above.

# %%
filepath = "../Data/Charlie/charlie.txt"

# open file
infile = open(filepath , "r")

# assign content to a varialbe
content = infile.read()

# close file
infile.close()


# do whatever you want with the context, e.g. print it:

print(content)
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.

# %% [markdown]
# ### 1.4.2 Using a context manager

# %% [markdown]
# There is actually an easier (and preferred) way to make sure that the file is closed as soon as you don't need it anymore, namely using what is called a **context manager**. Instead of using `open()` and `close()`, we use the  syntax shown below.
#
# The main advantage of using the with-statement is that it automatically closes the file once you leave the local context defined by the indentation level. If you 'manually' open and close the file, you risk forgetting to close the file. Therefore, context managers are considered a best-practice, and we will use the with-statement in all of our following code.

# %%
filepath = "../Data/Charlie/charlie.txt"

with open(filepath, "r") as infile:
    content = infile.read()
    
print(content)
# Out:
# Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells.
#
# Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.

# %% [markdown]
# # 2 Manipulating file content

# %% [markdown]
# Once your file content is loaded in a Python variable, you can manipulate its content as you can manipulate any other variable. You can edit it, add/remove lines, count word occurences, etc. Let's say we read the file content in a list of its lines as shown below. Note that we can use all of the different methods for reading files in the context manager.

# %%
filepath = "../Data/Charlie/charlie.txt"

with open(filepath, "r") as infile:
    lines = infile.readlines()
    
print(lines)
# Out:
# ['Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells. \n', '\n', 'Mr Wonka himself had suddenly become even more excited than usual, and anyone could see that this was the room he loved best of all. He was hopping about among the saucepans and the machines like a child among his Christmas presents, not knowing which thing to look at first. He lifted the lid from a huge pot and took a sniff; then he rushed over and dipped a finger into a barrel of sticky yellow stuff and had a taste; then he skipped across to one of the machines and turned half a dozen knobs this way and that; then he peered anxiously through the glass door of a gigantic oven, rubbing his hands and cackling with delight at what he saw inside. Then he ran over to another machine, a small shiny affair that kept going phut-phut-phut-phut-phut, and every time it went phut, a large green marble dropped out of it into a basket on the floor.']

# %% [markdown]
# Then we can for instance preserve only the first 2 lines of the file, in a new variable:

# %%
first_two_lines=lines[:2]
first_two_lines
# Out:
# ['Charlie Bucket stared around the gigantic room in which he now found himself. The place was like a witch’s kitchen! All about him black metal pots were boiling and bubbling on huge stoves, and kettles were hissing and pans were sizzling, and strange iron machines were clanking and spluttering, and there were pipes running all over the ceiling and walls, and the whole place was filled with smoke and steam and delicious rich smells. \n',
#  '\n']

# %% [markdown]
# We can count the lines that are longer than 15 characters:

# %%
counter=0
for line in lines:
    if len(line)>15:
        counter+=1
print(counter)

# %% [markdown]
# We will soon see how to perform text processing once we have loaded the file, by using an external module in the next chapter. But let's first write our modified file back to disk to preserve the changes.

# %% [markdown]
# # 3 Writing files

# %% [markdown]
# To write content to a file, we can open a new file and write the text to this file by using the **`write()`** method. Again, we can do this by using the context manager. Remember that we have to specify the **mode** using **`w`**.

# %% [markdown]
# Let's first slightly adapt our Charlie story by replacing the names in the text:

# %%
filepath = "../Data/Charlie/charlie.txt"

# read in file and assign content to the variable content
with open(filepath, "r") as infile:
    content = infile.read()
    
# manipulate content

your_name = "x y" #type in your name 
friends_name = "a b" #type in the name of a friend 

# Replace all instances of Charlie Bucket with your name and save it in new_content
new_content = content.replace("Charlie Bucket", your_name)

# Replace all instancs of Mr Wonka with your friends name and save it in new_new_content
new_new_content = new_content.replace("Mr Wonka", friends_name)

# %% [markdown]
# We can now save the manipulated content to a new file:

# %%
filename = "../Data/Charlie/charlie_new.txt"
with open(filename, "w") as outfile:
    outfile.write(new_new_content)

# %% [markdown]
# Open the file `charle_new.txt` in the folder `../Data/Charlie` in any text editor and read a personalized version of the story!

# %% [markdown]
# **Note about append mode (`a`):**
#
# The third mode of opening a file is *append* ('a'). If the file 'charlie_new.txt' does not exist, then append and write act the same: they create this new file and fill it with content. The difference between write and append occurs when this file would exist. In that case, the write mode overwrites its content, while the append mode adds the new content at the end of the existing one.

# %% [markdown]
# # 4 Reading and writing multiple files

# %% [markdown]
# You will often have multiple files to work with. The folder ../Data/Dreams contains 10 text files describing dreams of Vickie, a 10-year-old girl. These texts are extracted from [DreamBank](http://www.dreambank.net/).
#
# To process multiple files, we often want to *iterate* over a list of files. These files are usually stored in one or multiple directories on your computer.
#
# Instead of writing out every single file path, it is much more convenient to iterate over all the files in the directory `../Data/Dreams`. So we need to find a way to tell Python: "I want to do something with all these files at this location!"
#
# There are two modules which make dealing with multiple files a lot easier.
#
# * glob
# * os
#
# We will introduce them below.

# %% [markdown]
# ## 4.1 The `glob` module

# %% [markdown]
# The `glob` module is very useful to find all the pathnames matching a specified pattern according to the rules used by the Unix shell. You can use two wildcards: the asterisk (`*`) and the question mark (`?`). An asterisk matches zero or more characters in a segment of a name, while the question mark matches a single character in a segment of a name.
#
# For example, the following code gives all filenames in the directory `../Data/dreams`:

# %%
import glob

# %%
for filename in glob.glob("../Data/Dreams/*"):
    print(filename)
# Out:
# ../Data/Dreams/vickie8.txt
# ../Data/Dreams/vickie9.txt
# ../Data/Dreams/vickie10.txt
# ../Data/Dreams/IGNORE_ME!
# ../Data/Dreams/vickie7.txt
# ../Data/Dreams/vickie6.txt
# ../Data/Dreams/vickie4.txt
# ../Data/Dreams/vickie5.txt
# ../Data/Dreams/vickie1.txt
# ../Data/Dreams/vickie2.txt
# ../Data/Dreams/vickie3.txt

# %% [markdown]
# If we only want to consider text files and ignore everything else (here a file called 'IGNORE_ME!'), we can specify this in our search by only looking for files with the extension `.txt`:

# %%
for filename in glob.glob("../Data/Dreams/*.txt"):
    print(filename)
# Out:
# ../Data/Dreams/vickie8.txt
# ../Data/Dreams/vickie9.txt
# ../Data/Dreams/vickie10.txt
# ../Data/Dreams/vickie7.txt
# ../Data/Dreams/vickie6.txt
# ../Data/Dreams/vickie4.txt
# ../Data/Dreams/vickie5.txt
# ../Data/Dreams/vickie1.txt
# ../Data/Dreams/vickie2.txt
# ../Data/Dreams/vickie3.txt

# %% [markdown]
# A question mark (`?`) matches any single character in that position in the name. For example, the following code prints all filenames in the directory `../Data/dreams` that start with 'vickie' followed by exactly 1 character and end with the extension `.txt` (note that this will not print `vickie10.txt`):

# %%
for filename in glob.glob("../Data/Dreams/vickie?.txt"):
    print(filename)
# Out:
# ../Data/Dreams/vickie8.txt
# ../Data/Dreams/vickie9.txt
# ../Data/Dreams/vickie7.txt
# ../Data/Dreams/vickie6.txt
# ../Data/Dreams/vickie4.txt
# ../Data/Dreams/vickie5.txt
# ../Data/Dreams/vickie1.txt
# ../Data/Dreams/vickie2.txt
# ../Data/Dreams/vickie3.txt

# %% [markdown]
# You can also find filenames recursively by using the pattern `**` (the keyword argument `recursive` should be set to `True`), which will match any files and zero or more directories and subdirectories. The following code prints all files with the extension `.txt` in the directory `../Data/` and in all its subdirectories:

# %%
for filename in glob.glob("../Data/**/*.txt", recursive=True):
    print(filename)
# Out:
# ../Data/lyrics/walrus.txt
# ../Data/baby_names/national_data/yob2000.txt
# ../Data/baby_names/national_data/yob2014.txt
# ../Data/baby_names/national_data/yob1938.txt
# ../Data/baby_names/national_data/yob1910.txt
# ../Data/baby_names/national_data/yob1904.txt
# ../Data/baby_names/national_data/yob1905.txt
# ../Data/baby_names/national_data/yob1911.txt
# ../Data/baby_names/national_data/yob1939.txt
# ../Data/baby_names/national_data/yob2015.txt
# ../Data/baby_names/national_data/yob2001.txt
# ../Data/baby_names/national_data/yob2003.txt
# ../Data/baby_names/national_data/yob1907.txt
# ../Data/baby_names/national_data/yob1913.txt
# ../Data/baby_names/national_data/yob1898.txt
# ../Data/baby_names/national_data/yob1899.txt
# ../Data/baby_names/national_data/yob1912.txt
# ../Data/baby_names/national_data/yob1906.txt
# ../Data/baby_names/national_data/yob2002.txt
# ../Data/baby_names/national_data/yob2012.txt
# ../Data/baby_names/national_data/yob2006.txt
# ../Data/baby_names/national_data/yob1902.txt
# ../Data/baby_names/national_data/yob1916.txt
# ../Data/baby_names/national_data/yob1889.txt
# ../Data/baby_names/national_data/yob1888.txt
# ../Data/baby_names/national_data/yob1917.txt
# ../Data/baby_names/national_data/yob1903.txt
# ../Data/baby_names/national_data/yob2007.txt
# ../Data/baby_names/national_data/yob2013.txt
# ../Data/baby_names/national_data/yob2005.txt
# ../Data/baby_names/national_data/yob2011.txt
# ../Data/baby_names/national_data/yob1915.txt
# ../Data/baby_names/national_data/yob1901.txt
# ../Data/baby_names/national_data/yob1929.txt
# ../Data/baby_names/national_data/yob1928.txt
# ../Data/baby_names/national_data/yob1900.txt
# ../Data/baby_names/national_data/yob1914.txt
# ../Data/baby_names/national_data/yob2010.txt
# ../Data/baby_names/national_data/yob2004.txt
# ../Data/baby_names/national_data/yob1973.txt
# ../Data/baby_names/national_data/yob1967.txt
# ../Data/baby_names/national_data/yob1998.txt
# ../Data/baby_names/national_data/yob1999.txt
# ../Data/baby_names/national_data/yob1966.txt
# ../Data/baby_names/national_data/yob1972.txt
# ../Data/baby_names/national_data/yob1958.txt
# ../Data/baby_names/national_data/yob1964.txt
# ../Data/baby_names/national_data/yob1970.txt
# ../Data/baby_names/national_data/yob1971.txt
# ../Data/baby_names/national_data/yob1965.txt
# ../Data/baby_names/national_data/yob1959.txt
# ../Data/baby_names/national_data/yob1961.txt
# ../Data/baby_names/national_data/yob1975.txt
# ../Data/baby_names/national_data/yob1949.txt
# ../Data/baby_names/national_data/yob1948.txt
# ../Data/baby_names/national_data/yob1974.txt
# ../Data/baby_names/national_data/yob1960.txt
# ../Data/baby_names/national_data/yob1976.txt
# ../Data/baby_names/national_data/yob1962.txt
# ../Data/baby_names/national_data/yob1989.txt
# ../Data/baby_names/national_data/yob1988.txt
# ../Data/baby_names/national_data/yob1963.txt
# ../Data/baby_names/national_data/yob1977.txt
# ../Data/baby_names/national_data/yob1952.txt
# ../Data/baby_names/national_data/yob1946.txt
# ../Data/baby_names/national_data/yob1991.txt
# ../Data/baby_names/national_data/yob1985.txt
# ../Data/baby_names/national_data/yob1984.txt
# ../Data/baby_names/national_data/yob1990.txt
# ../Data/baby_names/national_data/yob1947.txt
# ../Data/baby_names/national_data/yob1953.txt
# ../Data/baby_names/national_data/yob1979.txt
# ../Data/baby_names/national_data/yob1945.txt
# ../Data/baby_names/national_data/yob1951.txt
# ../Data/baby_names/national_data/yob1986.txt
# ../Data/baby_names/national_data/yob1992.txt
# ../Data/baby_names/national_data/yob1993.txt
# ../Data/baby_names/national_data/yob1987.txt
# ../Data/baby_names/national_data/yob1950.txt
# ../Data/baby_names/national_data/yob1944.txt
# ../Data/baby_names/national_data/yob1978.txt
# ../Data/baby_names/national_data/yob1940.txt
# ../Data/baby_names/national_data/yob1954.txt
# ../Data/baby_names/national_data/yob1968.txt
# ../Data/baby_names/national_data/yob1983.txt
# ../Data/baby_names/national_data/yob1997.txt
# ../Data/baby_names/national_data/yob1996.txt
# ../Data/baby_names/national_data/yob1982.txt
# ../Data/baby_names/national_data/yob1969.txt
# ../Data/baby_names/national_data/yob1955.txt
# ../Data/baby_names/national_data/yob1941.txt
# ../Data/baby_names/national_data/yob1957.txt
# ../Data/baby_names/national_data/yob1943.txt
# ../Data/baby_names/national_data/yob1994.txt
# ../Data/baby_names/national_data/yob1980.txt
# ../Data/baby_names/national_data/yob1981.txt
# ../Data/baby_names/national_data/yob1995.txt
# ../Data/baby_names/national_data/yob1942.txt
# ../Data/baby_names/national_data/yob1956.txt
# ../Data/baby_names/national_data/yob2009.txt
# ../Data/baby_names/national_data/yob1919.txt
# ../Data/baby_names/national_data/yob1931.txt
# ../Data/baby_names/national_data/yob1925.txt
# ../Data/baby_names/national_data/yob1886.txt
# ../Data/baby_names/national_data/yob1892.txt
# ../Data/baby_names/national_data/yob1893.txt
# ../Data/baby_names/national_data/yob1887.txt
# ../Data/baby_names/national_data/yob1924.txt
# ../Data/baby_names/national_data/yob1930.txt
# ../Data/baby_names/national_data/yob1918.txt
# ../Data/baby_names/national_data/yob2008.txt
# ../Data/baby_names/national_data/yob1926.txt
# ../Data/baby_names/national_data/yob1932.txt
# ../Data/baby_names/national_data/yob1891.txt
# ../Data/baby_names/national_data/yob1885.txt
# ../Data/baby_names/national_data/yob1884.txt
# ../Data/baby_names/national_data/yob1890.txt
# ../Data/baby_names/national_data/yob1933.txt
# ../Data/baby_names/national_data/yob1927.txt
# ../Data/baby_names/national_data/yob1923.txt
# ../Data/baby_names/national_data/yob1937.txt
# ../Data/baby_names/national_data/yob1894.txt
# ../Data/baby_names/national_data/yob1880.txt
# ../Data/baby_names/national_data/yob1881.txt
# ../Data/baby_names/national_data/yob1895.txt
# ../Data/baby_names/national_data/yob1936.txt
# ../Data/baby_names/national_data/yob1922.txt
# ../Data/baby_names/national_data/yob1934.txt
# ../Data/baby_names/national_data/yob1920.txt
# ../Data/baby_names/national_data/yob1908.txt
# ../Data/baby_names/national_data/yob1883.txt
# ../Data/baby_names/national_data/yob1897.txt
# ../Data/baby_names/national_data/yob1896.txt
# ../Data/baby_names/national_data/yob1882.txt
# ../Data/baby_names/national_data/yob1909.txt
# ../Data/baby_names/national_data/yob1921.txt
# ../Data/baby_names/national_data/yob1935.txt
# ../Data/csv_data/Concreteness_ratings_Brysbaert_et_al_BRM.txt
# ../Data/linguistlist/example/2015-August.txt
# ../Data/authorship/C50/C50test/RobinSidel/347781newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/306379newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/324849newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/284041newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/363477newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/337819newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/350225newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/267356newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/37351newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/293670newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/270336newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/267130newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/344160newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/269930newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/303411newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/363336newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/302939newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/363245newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/352207newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/267467newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/315690newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/304717newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/324820newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/269611newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/284177newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/302146newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/27552newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/264346newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/32220newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/38072newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/304845newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/338537newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/375604newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/317780newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/372407newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/347154newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/275170newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/344040newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/264784newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/372617newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/268178newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/273201newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/341018newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/351734newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/305978newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/270064newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/292911newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/338553newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/271767newsML.txt
# ../Data/authorship/C50/C50test/RobinSidel/375629newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/516888newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/679778newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/340421newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/675753newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/639638newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/597530newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/63900newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/347842newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/692007newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/636476newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/685679newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/55512newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/672497newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/43494newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/511387newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/465820newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/636379newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/639556newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/37045newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/671745newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/334440newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/52569newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/672575newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/420768newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/663160newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/442294newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/360041newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/56273newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/642734newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/601534newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/407094newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/37073newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/619783newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/397543newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/353699newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/490772newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/452595newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/55464newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/432812newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/66810newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/669237newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/499374newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/465761newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/48188newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/404096newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/337350newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/565907newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/390774newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/613563newsML.txt
# ../Data/authorship/C50/C50test/LynnleyBrowning/481244newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/364308newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/586446newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/440833newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/467261newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/500025newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/340931newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/579258newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/357767newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/469597newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/413844newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/357728newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/519412newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/367345newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/585073newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/572318newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/560190newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/484584newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/415396newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/436678newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/472722newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/474506newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/469438newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/519442newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/479078newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/445118newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/460088newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/347274newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/442588newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/576094newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/559907newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/332794newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/506693newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/579892newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/494531newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/482048newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/396513newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/515693newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/491080newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/404573newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/578017newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/354282newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/491651newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/542251newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/333636newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/369687newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/579869newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/366916newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/359178newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/349979newsML.txt
# ../Data/authorship/C50/C50test/KouroshKarimkhany/357220newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/637058newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/430465newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/450775newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/625493newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/583420newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/600966newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/532335newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/526998newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/609836newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/616986newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/42763newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/462353newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/638970newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/491126newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/627633newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/430536newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/462265newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/534092newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/453294newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/520670newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/536857newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/622688newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/582683newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/517601newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/497480newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/459052newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/445797newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/436742newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/528737newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/489381newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/645726newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/469650newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/49586newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/540454newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/436431newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/506971newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/609390newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/542510newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/486895newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/534165newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/530677newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/520672newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/48231newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/633922newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/534156newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/634005newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/449088newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/528203newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/486930newsML.txt
# ../Data/authorship/C50/C50test/MichaelConnor/459205newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/47681newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/467057newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/455552newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/467485newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/440510newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/415575newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/450830newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/416007newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/467483newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/408154newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/46943newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/400547newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/414162newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/385567newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/457123newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/437354newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/398774newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/402351newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/379335newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/443467newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/385449newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/402056newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/379899newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/411346newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/414230newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/385962newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/413315newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/388736newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/427200newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/479838newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/466955newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/417119newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/415570newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/384184newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/48759newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/387359newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/419241newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/456850newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/424479newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/397370newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/418695newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/408807newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/379346newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/405201newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/482563newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/434168newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/413327newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/405061newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/388829newsML.txt
# ../Data/authorship/C50/C50test/JoeOrtiz/480979newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/456216newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/404458newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/328845newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/331353newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/320619newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/408364newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/553647newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/330573newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/515983newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/407529newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/382287newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/408417newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/483679newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/517645newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/412609newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/326019newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/416785newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/465164newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/561840newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/367137newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/525445newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/524749newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/323831newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/517487newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/331809newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/418649newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/556113newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/459981newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/457017newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/403143newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/418918newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/353279newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/431230newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/356361newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/333922newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/409470newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/367764newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/406430newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/316916newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/314122newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/482711newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/337716newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/535691newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/523278newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/539148newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/374573newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/470368newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/382538newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/365349newsML.txt
# ../Data/authorship/C50/C50test/EricAuchard/337934newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/492068newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/517526newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/606238newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/469448newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/635785newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/421829newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/466275newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/491060newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/42764newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/593702newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/450788newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/479564newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/424074newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/544012newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/602453newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/600865newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/493995newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/539259newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/494466newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/593715newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/582759newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/482034newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/433558newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/518507newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/507230newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/601962newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/492770newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/439561newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/436774newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/653225newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/486982newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/629404newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/650163newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/43033newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/478157newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/605443newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/582927newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/630942newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/581517newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/637021newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/566383newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/496933newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/608287newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/583229newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/602451newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/491643newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/595361newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/450383newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/493876newsML.txt
# ../Data/authorship/C50/C50test/AaronPressman/64508newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/524096newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/567680newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/496143newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/626000newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/604722newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/662139newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/490233newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/514480newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/565499newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/516664newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/608563newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/567184newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/580087newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/496100newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/552126newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/624144newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/480957newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/627635newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/581808newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/493188newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/585685newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/626136newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/633059newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/634641newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/585649newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/485513newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/534898newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/650856newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/600532newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/655704newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/563766newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/625951newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/578465newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/493177newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/580082newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/631455newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/600570newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/562272newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/583527newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/553261newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/658808newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/572910newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/598856newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/567293newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/643780newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/519956newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/589488newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/642555newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/488153newsML.txt
# ../Data/authorship/C50/C50test/SimonCowell/510928newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/448512newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/394110newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/392189newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/431745newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/34786newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/402635newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/431701newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/30159newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/342460newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/46320newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/29644newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/470975newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/351174newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/399130newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/397899newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/358776newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/399889newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/426695newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/413503newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/368201newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/383194newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/358806newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/394081newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/374038newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/474810newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/42284newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/480355newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/30150newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/396710newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/426864newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/399373newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/4587newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/392383newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/461113newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/329704newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/434690newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/4680newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/409029newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/329320newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/422342newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/308675newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/336018newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/334764newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/444232newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/467877newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/326546newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/451502newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/34681newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/437962newsML.txt
# ../Data/authorship/C50/C50test/LynneO'Donnell/441368newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/311197newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/347916newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/232587newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/232185newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/239175newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/255821newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/297212newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/239190newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/311202newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/254322newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/331647newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/299970newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/337133newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/355041newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/240426newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/303705newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/319311newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/358016newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/255765newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/290492newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/343315newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/298705newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/36015newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/239177newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/314446newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/266476newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/344955newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/327640newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/241063newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/352437newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/232139newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/322428newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/331632newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/308096newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/309658newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/309691newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/237949newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/320924newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/303604newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/312577newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/351972newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/237920newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/240680newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/32950newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/352479newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/31097newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/253043newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/286508newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/232106newsML.txt
# ../Data/authorship/C50/C50test/EdnaFernandes/313399newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/304275newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/361836newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/386125newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/4547newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/34572newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/426474newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/313525newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/431629newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/425090newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/365713newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/441280newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/419311newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/304260newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/402410newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/446953newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/373912newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/473549newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/392062newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/304272newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/426489newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/38625newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/441794newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/382156newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/369421newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/422170newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/408899newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/36584newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/416113newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/38618newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/373905newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/470788newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/422211newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/448400newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/36582newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/428363newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/434637newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/392090newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/469950newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/31244newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/373952newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/34580newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/373931newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/437822newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/34544newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/313543newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/389342newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/416138newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/40200newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/402400newsML.txt
# ../Data/authorship/C50/C50test/KevinMorrison/422172newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/450789newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/482988newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/537165newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/373188newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/518462newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/54326newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/481676newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/330838newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/523317newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/409512newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/437596newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/480032newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/457404newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/532788newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/437625newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/429028newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/5163newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/333634newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/503783newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/431299newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/463536newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/434351newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/445921newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/376599newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/549215newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/536837newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/33692newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/506467newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/39437newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/503493newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/537137newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/544003newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/317690newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/357910newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/5229newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/502726newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/54813newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/374379newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/43927newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/417863newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/54325newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/532287newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/392661newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/432444newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/503492newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/449017newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/424095newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/318846newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/398046newsML.txt
# ../Data/authorship/C50/C50test/SamuelPerry/328823newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/363833newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/2911newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/357273newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/391498newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/407636newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/391445newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/335312newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/35005newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/390115newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/302920newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/384813newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/456459newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/294155newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/29747newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/415401newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/404398newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/429308newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/466395newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/386926newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/398230newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/351736newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/433550newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/450332newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/350167newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/43225newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/33704newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/360832newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/303107newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/303415newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/413779newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/357162newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/386989newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/404985newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/404426newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/347178newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/314014newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/397964newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/436695newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/388381newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/384968newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/343984newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/388386newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/384992newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/334989newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/391260newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/331817newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/388290newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/32110newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/293689newsML.txt
# ../Data/authorship/C50/C50test/PatriciaCommins/404982newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/371679newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/508613newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/352438newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/434117newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/499321newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/483777newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/353739newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/39590newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/471617newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/327808newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/372062newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/465748newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/350526newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/59545newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/320888newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/448230newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/359937newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/420831newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/321184newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/505949newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/435563newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/356695newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/505971newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/318112newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/298942newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/356689newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/432870newsML.txt
# ../Data/authorship/C50/C50test/JohnMastrini/28628newsML.txt
# ...
# ../Data/authorship/C50/C50train/GrahamEarnshaw/128171newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/271168newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/217296newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/187405newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/277010newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/232939newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/250860newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/258604newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/238773newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/252118newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/271134newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/152163newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/231139newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/204791newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/167951newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/254834newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/205033newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/247765newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/232804newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/114251newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/270340newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/190410newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/244929newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/274219newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/169618newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/280504newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/220126newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/262722newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/265664newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/113070newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/232537newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/262829newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/134309newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/226150newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/249198newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/181135newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/241254newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/231076newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/13495newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/198148newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/113102newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/201228newsML.txt
# ../Data/authorship/C50/C50train/GrahamEarnshaw/267059newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/155005newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/103816newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/223856newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/148778newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/223842newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/111971newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/322996newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/294933newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/25315newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/250680newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/181034newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/33299newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/218591newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/25320newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/355589newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/154997newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/322990newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/242252newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/30677newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/223857newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/118434newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/111981newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/25344newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/118470newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/117740newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/118448newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/294952newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/361820newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/148786newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/361792newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/323527newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/18328newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/31892newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/165020newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/151764newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/198061newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/110697newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/201116newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/184099newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/118901newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/361793newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/184111newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/176080newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/33301newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/165334newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/164986newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/33315newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/118472newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/354020newsML.txt
# ../Data/authorship/C50/C50train/BernardHickey/174426newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/219536newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/181858newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162195newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162181newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/314406newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/181907newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/36556newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/315603newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/165832newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162193newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/239217newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/23873newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/250064newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/394816newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/188419newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/314384newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/327620newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/163119newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/278254newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/103790newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/341864newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/157761newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/163112newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/322955newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/316041newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/294355newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/267983newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/199262newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/347828newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/254351newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/341840newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/187985newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/167814newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162644newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162191newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/329130newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/164526newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/402055newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/27422newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/393388newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/340175newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/359687newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/156083newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/371805newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/189900newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/297203newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/322479newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/189882newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/162189newsML.txt
# ../Data/authorship/C50/C50train/KirstinRidley/374916newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/268005newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/289578newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/223793newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/164558newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/18111newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/236412newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/240608newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/179671newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/225590newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/224655newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/304231newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/274612newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/29098newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/172146newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/134595newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/21127newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/164269newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/135627newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/134290newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/110282newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/239202newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/164287newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/237953newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/107525newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/307212newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/141391newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/185613newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/238090newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/162656newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/141943newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/223283newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/188417newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/302382newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/300452newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/134584newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/18227newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/162657newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/223300newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/251540newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/23876newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/220666newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/219521newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/272743newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/165875newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/134983newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/184789newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/16167newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/219512newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/144367newsML.txt
# ../Data/authorship/C50/C50train/AlexanderSmith/109096newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/219628newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/216822newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/13810newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/15592newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/319107newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/185720newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/319113newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/346330newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/172241newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/311319newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/332252newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/353567newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/227933newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/165902newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/316724newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/139760newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/164298newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/356565newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/326409newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/202140newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/213719newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/254426newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/239275newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/345128newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/302437newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/305250newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/339037newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/362785newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/364632newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/163197newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/257337newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/130081newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/329147newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/212440newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/334277newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/105793newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/308198newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/2387newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/239280newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/230638newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/10274newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/317743newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/162222newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/174373newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/366471newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/224725newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/233590newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/207278newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/236474newsML.txt
# ../Data/authorship/C50/C50train/LydiaZajc/188535newsML.txt
# ../Data/books/AnnaKarenina.txt
# ../Data/books/HuckFinn.txt
# ../Data/books/Macbeth.txt
# ../Data/SUBTLEX-US/SUBTLEXus74286wordstextversion.txt
# ../Data/Charlie/charlie_new.txt
# ../Data/Charlie/charlie.txt
# ../Data/LCohen/12926778.txt
# ../Data/LCohen/12927149.txt
# ../Data/LCohen/12926915.txt
# ../Data/LCohen/12927000.txt
# ../Data/LCohen/12927831.txt
# ../Data/LCohen/12928269.txt
# ../Data/LCohen/12926845.txt
# ../Data/LCohen/12928011.txt
# ../Data/LCohen/12926940.txt
# ../Data/LCohen/12930113.txt
# ../Data/Dreams/vickie8.txt
# ../Data/Dreams/vickie9.txt
# ../Data/Dreams/vickie10.txt
# ../Data/Dreams/vickie7.txt
# ../Data/Dreams/vickie6.txt
# ../Data/Dreams/vickie4.txt
# ../Data/Dreams/vickie5.txt
# ../Data/Dreams/vickie1.txt
# ../Data/Dreams/vickie2.txt
# ../Data/Dreams/vickie3.txt
# ../Data/RedCircle/RedCircle.txt

# %% [markdown]
# ## 4.2 The `os` module

# %% [markdown]
# Another module that you will frequently see being used in examples is the `os` module. The `os` module has many features that can be very useful and which are not supported by the `glob` module. We will not go over each and every useful method here, but here's a list of some of the things that you can do (some of which we have seen above):
#
# - creating single or multiple directories: `os.mkdir()`, `os.mkdirs()`;
# - removing single or multiple directories: `os.rmdir()`, `os.rmdirs()`;
# - checking whether something is a file or a directory: `os.path.isfile()`, `os.path.isdir()`;
# - split a path and return a tuple containing the directory and filename: `os.path.split()`;
# - construct a pathname out of one or more partial pathnames: `os.path.join()`
# - split a filename and return a tuple containing the filename and the file extension: `os.path.splitext()`
# - get only the basename or the directory path: `os.path.basename()`, `os.path.dirname()`.
#
# Feel free to ply around with these methods and figure out how they work yourself :-)

# %%
# Start by importing the module:
import os

# let's use a filepath for testing it out:
filepath = "../Data/Charlie/charlie.txt"
os.path.basename(filepath)
# Out:
# 'charlie.txt'

# %% [markdown]
# # Exercises

# %% [markdown]
# **Exercise 1:**
#
# Write a program that opens `RedCircle.txt` in the `../Data/RedCircle` folder and prints its content as a single string:

# %%
# your code here

# %% [markdown]
# **Exercise 2:**
#
# Write a program that opens `RedCircle.txt` in the `../Data/RedCircle` folder and prints a list containing all lines in the file:

# %%
# your code here

# %% [markdown]
# **Exercise 3:**
#
# Create a counter dictionary like in block 2 (the dictionaries chapter), where you will count the number of occurences of each word in a file.

# %%
# your code here

# %% [markdown]
# **Exercise 4:**
#
# The module `os` implements functions that allow us to work with the operating system (see folder contents, change directory, etc.). Use the function `listdir` from the module `os` to see the contents of the current directory. Then print all the items that do not start with a dot.

# %%
# your code here
